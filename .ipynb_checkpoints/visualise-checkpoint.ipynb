# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("out.csv")
df.drop(['Timestamp'], axis=1, inplace=True)
# df.head()
grouped = df.groupby('mthly-income')
# grouped.describe()
plot = sns.catplot(x="mthly-income", y="cgpa", hue='school', data=df)
plot.fig.autofmt_xdate() # prevent the x-axis text from overlapping
